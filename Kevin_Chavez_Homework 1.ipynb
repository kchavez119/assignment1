# %% [markdown]
# Professor: Apostolos Filippas
#
# Class: Web Analytics
#
# Topic: Assignment 1
#
# **You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.**
#
# # <center><font color='red'>Instructions </font></center>
#
# In this homework you are asked to do a basic data analysis using a real-life dataset downloaded from www.politifact.com .
#
# You will be asked to do things step by step. Please follow the guidelines and write your code in the code cells provided.
# - Feel free to comment your code as well as you think your code should be commented.
# - There are multiple correct ways to answer each question!
# - The analysis that is required is similar to the Python #3 notebook. Look to this notebook for hints!

# %% [markdown]
# ## Q1 - Understanding your data source
#
# Visit the www.politifact.com website and browse around. What is the main function of the website?

# %% [markdown]
# the purpose of the website is to fact-check politicians statements and or claims

# %% [markdown]
# ## Q2 - Data format and attributes
#
# Your data file has been pulled from the politifact website. It can be downloaded from the following link https://bit.ly/politifactData.
#
# Every line represents a different political statement that politifact has put under its microscope. The tab-separated features are the following:
# 1. Politifact Rating
# 2. Statement
# 3. Who made the statement
# 4. when the statement was made
# 5. where the statement was made
# 6. '|'-separated subjects of the statement
#
# Put the data into a list named **statements**.
# - Every element of the list should be a list with the 6 features mentioned above.
# - The 6th element of the list of features should be a list containing the subjects that the corresponding statement is about.
# - Print the entry with index 37

# %%
my_file = open ('politifact_data.txt', mode = 'r', encoding = 'utf-8')

data = my_file.read()

my_file.close()

statements = data.split('\n')

for i in range(0,len(statements)):
    statements[i] = statements[i].split('\t')
    statements[i][5] = statements[i][5].split('|')
print(statements[37])
# Out:
# ['True', ' After shedding jobs for more than 10 years, our manufacturers have added about 500,000 jobs over the past three. ', 'barack-obama', 'Tuesday, February 12th, 2013', 'in the State of the Union Address', ['economy', 'jobs']]

# %% [markdown]
# ## Q3 - The set of ratings
#
# Use your data to find all possible ratings that politifact might assign to a statement. In other words, all possible values that the first attribute can take. Store them into a set with name **ratings** and print the set.

# %%
ratings = set()

for i in range(0,len(statements)):
    ratings.add(statements[i][0])
print(ratings)
# Out:
# {'Pants on Fire!', 'Half-True', 'False', 'No Flip', 'True', 'Full Flop', 'Mostly True', 'Half Flip', 'Mostly False'}

# %% [markdown]
# ## Q4 - The distribution of ratings
#
# You are now asked to find how many times each of the possible ratings appears.
#
# I suggest you do that using a disctionary (with keys being the rating string, and values being the number of times it appears) but feel free to follow your own strategy.
#
# Print the distribution of ratings.

# %%
num_ratings = dict()

for i in range(0,len(statements)):
    if statements[i][0] in num_ratings:
        num_ratings[  statements[i][0]  ] += 1
    else:
        num_ratings[  statements[i][0]  ] = 1

print(num_ratings)
# Out:
# {'Mostly False': 689, 'Mostly True': 787, 'Half-True': 891, 'False': 820, 'Pants on Fire!': 402, 'True': 643, 'Half Flip': 14, 'No Flip': 7, 'Full Flop': 44}

# %% [markdown]
# ## Q5 - Changing labels to binary
#
# Not all of the ratings seem to tell us confidently that the statement is a lie; for example some of them refer to whether the quoter has flopped on a previous statement they made, or that the statement is half true.
#
# Toward that end make a new list with name **new_statements** that contains only those entries for which the rating is 'False', 'Mostly False', 'Pants on Fire!', 'Mostly True', and 'True'.
#
# After you do this, turn the old ratings into 0 or 1 's as follows:
# - 'False', 'Mostly False', 'Pants on Fire!' should be mapped to 0
# - 'Mostly True', 'True' should be mapped to 1

# %%
new_statements = list ()

for i in range(0,len(statements)):
    if statements[i][0] == 'True':
        new_statements.append(statements[i][0:])
    elif statements[i][0] == 'Mostly True':
        new_statements.append(statements[i][0:])
    elif statements[i][0] == 'False':
        new_statements.append(statements[i][0:])
    elif statements[i][0] == 'Mostly False':
        new_statements.append(statements[i][0:])
    elif statements[i][0] == 'Pants on Fire!':
        new_statements.append(statements[i][0:])

# %%
zero = [0]
one = [1]

for i in range(0,len(new_statements)):
    if new_statements[i][0] == 'True':
        new_statements[i][0] = one[0]
    elif new_statements[i][0] == 'Mostly True':
        new_statements[i][0] = one[0]
    elif new_statements[i][0] == 'False':
        new_statements[i][0] = zero[0]
    elif new_statements[i][0] == 'Mostly False':
        new_statements[i][0] = zero[0]
    elif new_statements[i][0] == 'Pants on Fire!':
        new_statements[i][0] = zero[0]
new_statements
# Out:
# [[0,
#   ' Ted Cruz tried to ban contraception  five times.',
#   'hillary-clinton',
#   'Tuesday, December 1st, 2015',
#   'in a post on her campaign website',
#   ['abortion', 'health-care']],
#  [1,
#   ' It is already in the law that there is a requirement to screen (refugees) for religion. ',
#   'jeb-bush',
#   'Sunday, November 29th, 2015',
#   'in an interview on Face the Nation',
#   ['foreign-policy', 'religion', 'terrorism']],
#  [0,
#   'The tax policies of George W. Bush  created a dynamic effect of high growth. ',
#   'jeb-bush',
#   'Sunday, September 27th, 2015',
#   'in an interview on Fox News Sunday',
#   ['economy', 'taxes']],
#  [0,
#   ' The president is advocating a drone strike program in America. ',
#   'rand-paul',
#   'Wednesday, March 6th, 2013',
#   'in a tweet',
#   ['civil-rights', 'terrorism']],
#  [0,
#   'Of $60 billion Congress approved in response to Hurricane Sandy,  only 10 percent was for disaster relief. ',
#   'al-cardenas',
#   'Friday, March 1st, 2013',
#   'in an interview on MSNBC’s Morning Joe',
#   ['federal-budget']],
#  [0,
#   ' There s no plan from Senate Democrats or the White House to replace the sequester. ',
#   'john-boehner',
#   'Sunday, March 3rd, 2013',
#   'in an interview on Meet the Press.',
#   ['federal-budget']],
#  [1,
#   'Says a majority of Americans -- and Republicans -- support his approach for deficit reduction.',
#   'barack-obama',
#   'Friday, March 1st, 2013',
#   'in a press briefing at the White House',
#   ['federal-budget', 'polls', 'taxes']],
#  [0,
#   'Due to the sequester,  people are going to be unsafe. Homes are going to burn. ',
#   'ami-bera',
#   'Tuesday, February 26th, 2013',
#   'in a House floor speech',
#   ['federal-budget']],
#  [0,
#   ' There are literally teachers now who are getting pink slips  because of sequestration.',
#   'arne-duncan',
#   'Sunday, February 24th, 2013',
#   'in an appearance on Face the Nation.',
#   ['education', 'federal-budget']],
#  [0,
#   'Says the federal government is earning more tax revenue now  than any other time. ',
#   'kevin-mccarthy',
#   'Monday, February 25th, 2013',
#   'in an interview on Fox News',
#   ['economy', 'federal-budget', 'taxes']],
#  [1,
#   ' There s going to be a slowdown and delays in flights  as a result of the sequester.',
#   'raymond-lahood',
#   'Monday, February 25th, 2013',
#   'in an interview on MSNBC',
#   ['federal-budget', 'transportation']],
#  [0,
#   'There is not  one of the Muslim nations  that doesn t have  discrimination against women, discrimination against gays, subjugation of other religious beliefs. ',
#   'ben-carson',
#   'Tuesday, September 22nd, 2015',
#   'in an interview with Foxs The Kelly File',
#   ['corrections-and-updates',
#    'gays-and-lesbians',
#    'human-rights',
#    'islam',
#    'religion',
#    'women']],
#  [1,
#   ' When I ran against incumbent President Gerald Ford, you know how much money we raised? None. ',
#   'jimmy-carter',
#   'Thursday, February 21st, 2013',
#   'in an interview with CNNs Piers Morgan',
#   ['campaign-finance']],
#  [0,
#   'If the sequester hits, federal prosecutors will have to  let criminals go. ',
#   'barack-obama',
#   'Tuesday, February 19th, 2013',
#   'in a speech in Washington, D.C. ',
#   ['crime', 'criminal-justice', 'federal-budget', 'legal-issues']],
#  [1,
#   'The sequester  won t consider whether we re cutting some bloated program that has outlived its usefulness, or a vital service that Americans depend on every single day. It doesn t make those distinctions. ',
#   'barack-obama',
#   'Tuesday, February 19th, 2013',
#   'in a speech in Washington, D.C.',
#   ['federal-budget']],
#  [0,
#   'Says after Hurricane Sandy, New York Mayor Michael Bloomberg  refused to allow the National Guard into the city to restore civil order because Guardsmen carry guns! ',
#   'wayne-lapierre',
#   'Wednesday, February 13th, 2013',
#   'in an article in the Daily Caller',
#   ['guns', 'public-safety']],
#  [0,
#   ' The president flagrantly defies the 2006 federal law ordering the construction of a secure border fence along the entire Mexican border. ',
#   'wayne-lapierre',
#   'Wednesday, February 13th, 2013',
#   'in an op-ed for the Daily Caller',
#   ['immigration']],
#  [0,
#   ' Phoenix is already one of the kidnapping capitals of the world. ',
#   'wayne-lapierre',
#   'Wednesday, February 13th, 2013',
#   'in an op-ed in the Daily Caller',
#   ['crime']],
#  [1,
#   ' The majority of (the American people) voted for a Democratic House. ',
#   'steny-hoyer',
#   'Tuesday, February 12th, 2013',
#   'in a media availability with reporters',
#   ['congress', 'elections']],
#  [0,
#   ' When (Ronald) Reagan came in, from 1978 to 1982, economic growth averaged less than 1 percent a year. There s only one other four-year period where that s true. That s true from 2008 to 2012. ',
#   'ted-cruz',
#   'Monday, September 21st, 2015',
#   'in an interview with CBS Stephen Colbert',
#   ['economy', 'history', 'jobs']],
#  [1,
#   'Says wrestling was a favorite sport of Abraham Lincoln.',
#   'donald-rumsfeld',
#   'Sunday, February 17th, 2013',
#   'in an op-ed in the Washington Post',
#   ['history', 'sports']],
#  [0,
#   'Says of a failed cloture vote on nominating Chuck Hagel for defense secretary:  This is not a filibuster. ',
#   'john-cornyn',
#   'Thursday, February 14th, 2013',
#   'in a speech on the Senate floor',
#   ['congress', 'congressional-rules']],
#  [1,
#   ' The 12 hottest years on record have come in the last 15 years. ',
#   'barack-obama',
#   'Tuesday, February 12th, 2013',
#   'in the State of the Union Address',
#   ['environment']],
#  [1,
#   'Says he and Mitt Romney agreed on tying minimum wage increases to inflation.',
#   'barack-obama',
#   'Tuesday, February 12th, 2013',
#   'in the State of the Union address',
#   ['poverty', 'workers']],
#  [0,
#   ' We have doubled the distance our cars will go on a gallon of gas. ',
#   'barack-obama',
#   'Tuesday, February 12th, 2013',
#   'in the State of the Union address',
#   ['energy', 'environment']],
#  [0,
#   ' Throughout, we have kept Congress fully informed of our efforts  to create a legal framework on counterterrorism.',
#   'barack-obama',
#   'Tuesday, February 12th, 2013',
#   'in the State of the Union Address',
#   ['legal-issues', 'terrorism']],
#  [1,
#   'Says  overwhelming majorities of Americans  support gun legislation  like background checks. ',
#   'barack-obama',
#   'Tuesday, February 12th, 2013',
#   'in the State of the Union Address',
#   ['civil-rights', 'crime', 'guns']],
#  [0,
#   ' The birther movement was started by Hillary Clinton in 2008. She was all in!    ',
#   'donald-trump',
#   'Tuesday, September 22nd, 2015',
#   'in a tweet',
#   ['obama-birth-certificate']],
#  [1,
#   ' After shedding jobs for more than 10 years, our manufacturers have added about 500,000 jobs over the past three. ',
#   'barack-obama',
#   'Tuesday, February 12th, 2013',
#   'in the State of the Union Address',
#   ['economy', 'jobs']],
#  [1,
#   ' With the exception of slavery and the Chinese Exclusion Act, our laws have never barred persons from becoming citizens. ',
#   'zoe-lofgren',
#   'Tuesday, February 5th, 2013',
#   'in a House hearing on immigration',
#   ['immigration']],
#  [0,
#   'Research shows that  a vast majority of arriving immigrants today come here because they believe that government is the source of prosperity, and that s what they support. ',
#   'rush-limbaugh',
#   'Tuesday, January 29th, 2013',
#   'in a radio interview',
#   ['immigration', 'pundits']],
#  [1,
#   'Says since Australia passed tough gun laws,  homicides by firearm have declined almost 60 percent. ',
#   'stephen-king',
#   'Friday, January 25th, 2013',
#   'in a Kindle Single essay, Guns',
#   ['crime', 'government-regulation', 'guns', 'public-safety']],
#  [0,
#   'Says Chuck Hagel has called for  an end to our nuclear program. ',
#   'americans-strong-defense',
#   'Monday, January 21st, 2013',
#   'in a television ad',
#   ['foreign-policy', 'nuclear']],
#  [1,
#   ' One out of every five law enforcement officers that s killed is killed with an assault weapon. ',
#   'dianne-feinstein',
#   'Sunday, January 27th, 2013',
#   'in an interview on CBS Face the Nation',
#   ['crime', 'guns']],
#  [1,
#   'Says  the cascading effects  of climate change contributed to the rise of ISIS.',
#   'martin-omalley',
#   'Thursday, September 10th, 2015',
#   'in interview with Democracy Now!',
#   ['climate-change', 'environment', 'foreign-policy', 'terrorism']],
#  [0,
#   'Under President Barack Obama,  8.3 (million) fewer Americans are working today than there were four years ago. ',
#   'sean-hannity',
#   'Sunday, January 20th',
#   ' 2013 in his Fox News show',
#   ['economy', 'jobs', 'pundits']],
#  [1,
#   'The tax penalty that the government imposes if you don t buy health insurance  is lower than it would have cost to buy insurance. ',
#   'ron-desantis',
#   'Monday, January 21st, 2013',
#   'in an interview on Fox News',
#   ['health-care']],
#  [1,
#   ' Even members of the NRA, when they were polled recently, were under the impression that everyone has a criminal background check. ',
#   'jackie-speier',
#   'Tuesday, January 15th, 2013',
#   'in an MSNBC interview',
#   ['civil-rights', 'crime', 'guns']],
#  [0,
#   ' Poverty levels (are) at an all-time high. ',
#   'bernie-s',
#   'Monday, January 7th, 2013',
#   'in an interview on MSNBC',
#   ['poverty']],
#  [1,
#   'Since 1968,  more Americans have died from gunfire than died in   all the wars of this country s history. ',
#   'mark-shields',
#   'Friday, December 21st, 2012',
#   'in the PBS NewsHour',
#   ['guns']],
#  [1,
#   'In 2011, more people were murdered with knives,  hands or feet  or  clubs and hammers  than with any type of rifle.',
#   'facebook-posts',
#   'Tuesday, January 8th, 2013',
#   'in on Facebook',
#   ['guns']],
#  [0,
#   ' While President Obama says all options are on the table for preventing a nuclear Iran, Hagel says military action is not a viable, feasible, responsible option. ',
#   'emergency-committee-israel',
#   'Wednesday, December 19th, 2012',
#   'in an ad',
#   ['foreign-policy', 'israel', 'military']],
#  [1,
#   'AIG has fully repaid the federal government  plus a profit of more than $22 billion. ',
#   'american-international-group',
#   'Tuesday, January 1st, 2013',
#   'in a TV ad',
#   ['corporations', 'federal-budget', 'financial-regulation']],
#  [1,
#   ' This week the House of Representatives voted to remove the word  lunatic  from federal law. ',
#   'allen-west',
#   'Saturday, December 8th, 2012',
#   'in a weekly newsletter',
#   ['legal-issues']],
#  [1,
#   ' Under Republicans, recessions happen four times as frequently as under Democrats.    ',
#   'hillary-clinton',
#   'Saturday, September 19th, 2015',
#   'in remarks at the 2015 New Hampshire Democratic Party State Convention',
#   ['economy']],
#  [1,
#   'Says Walmart employees represent the largest group of Medicaid and food stamp recipients in many states, costing the taxpayer $1,000 per worker.',
#   'alan-grayson',
#   'Saturday, November 24th, 2012',
#   'in a Huffington Post column',
#   ['corporations', 'medicaid', 'welfare', 'workers']],
#  [0,
#   ' Mitt Romney made over a hundred million dollars by shutting down (a Marion, Ind. paper) plant. ',
#   'priorities-usa-action',
#   'Friday, November 2nd, 2012',
#   'in in a TV ad',
#   ['candidates-biography', 'corporations', 'message-machine-2012']],
#  [1,
#   'Says Mitt Romney  was director of a company that stole millions from Medicare. ',
#   'priorities-usa-action',
#   'Wednesday, October 31st, 2012',
#   'in a campaign ad',
#   ['medicare']],
#  [0,
#   'Says during George W. Bush s administration  we were losing millions of jobs per month,  while under Barack Obama we have  three years of gaining hundreds of thousands of jobs per month. ',
#   'michael-moore',
#   'Friday, November 2nd, 2012',
#   'in a tweet',
#   ['economy', 'history', 'jobs']],
#  [0,
#   'Says Mitt Romney wants to  get rid of Planned Parenthood. ',
#   'planned-parenthood-action-fund',
#   'Wednesday, October 31st, 2012',
#   'in a radio ad',
#   ['abortion', 'federal-budget', 'health-care']],
#  [0,
#   'Says  Romney supported a law that could have made most common forms of birth control illegal. ',
#   'florida-democratic-party',
#   'Friday, October 26th, 2012',
#   'in a mailer to voters',
#   ['abortion', 'sexuality']],
#  [0,
#   'An Obama campaign tactic for rallying voters is to  offer them cell phones. ',
#   'adam-putnam',
#   'Wednesday, October 31st, 2012',
#   'in at a Romney campaign rally',
#   ['campaign-advertising']],
#  [1,
#   'Says  Mitt Romney s plan rolls back regulations  on banks.',
#   'barack-obama',
#   'Saturday, October 27th, 2012',
#   'in a television ad',
#   ['financial-regulation', 'message-machine-2012']],
#  [0,
#   'Says Bernie Sanders opposes  requiring all children to have a K-12 education. ',
#   'viral-image',
#   'Tuesday, September 8th, 2015',
#   'in a shareable graphic on the Web',
#   ['education']],
#  [0,
#   'Says Barack Obama  sold Chrysler to Italians who are going to build Jeeps in China  at the cost of American jobs.',
#   'mitt-romney',
#   'Monday, October 29th, 2012',
#   'in a television ad',
#   ['china', 'jobs', 'message-machine-2012', 'workers']],
#  [0,
#   ' Under President Obama: $4,000 tax hike on middle-class families. ',
#   'mitt-romney',
#   'Wednesday, October 10th, 2012',
#   'in a campaign ad',
#   ['message-machine-2012', 'taxes']],
#  [0,
#   'Says GM used taxpayer dollars to prop up operations in China.',
#   'let-freedom-ring',
#   'Monday, October 15th, 2012',
#   'in a Web video',
#   ['china', 'jobs', 'message-machine-2012']],
#  [0,
#   ' The sequester is not something that I ve proposed. It is something that Congress has proposed. ',
#   'barack-obama',
#   'Monday, October 22nd, 2012',
#   'in a presidential debate',
#   ['debates', 'federal-budget', 'military']],
#  [1,
#   'Says Mitt Romney wants to add $2 trillion to defense budget that the military hasn t asked for.',
#   'barack-obama',
#   'Monday, October 22nd, 2012',
#   'in a presidential debate',
#   ['debates', 'military']],
#  [0,
#   'Says Barack Obama was silent on Iran  when the students took to the streets in Tehran and the people there protested, (and) the Green Revolution occurred. ',
#   'mitt-romney',
#   'Monday, October 22nd, 2012',
#   'in a foreign policy debate',
#   ['debates', 'foreign-policy']],
#  [1,
#   ' Pakistan has 100 nuclear warheads and they re rushing to build a lot more. They ll have more than Great Britain sometime in the relatively near future. ',
#   'mitt-romney',
#   'Monday, October 22nd, 2012',
#   'in the third presidential debate in Boca Raton, Fla.',
#   ['foreign-policy', 'nuclear']],
#  [1,
#   'When Carly Fiorina says Hewlett-Packard  revenues went up, that s because she bought Compaq. It was a terrible deal. ',
#   'donald-trump',
#   'Wednesday, September 16th, 2015',
#   'in the second GOP primary debate',
#   ['candidates-biography', 'job-accomplishments', 'technology']],
#  [1,
#   'Says Mitt Romney  just gave a speech a few weeks ago  and said  we should still have troops in Iraq. ',
#   'barack-obama',
#   'Monday, October 22nd, 2012',
#   'in the third presidential debate',
#   ['debates', 'iraq', 'military']],
#  [0,
#   'Says Mitt Romney was clear that he  would not provide government assistance to the U.S. auto companies, even if they went through bankruptcy. ',
#   'barack-obama',
#   'Monday, October 22nd, 2012',
#   'in the final debate',
#   ['debates', 'jobs']],
#  [1,
#   ' I went to the Olympics that was out of balance, and we got it on balance. ',
#   'mitt-romney',
#   'Monday, October 22nd, 2012',
#   'in the third presidential debate in Boca Raton, Fla.',
#   ['candidates-biography']],
#  [1,
#   ' The president said he was going to create daylight between ourselves and Israel. ',
#   'mitt-romney',
#   'Monday, October 22nd, 2012',
#   'in a presidential debate',
#   ['debates', 'israel']],
#  [1,
#   'Says a university survey concluded his Massachusetts administration  had more women in senior leadership positions than any other state in America. ',
#   'mitt-romney',
#   'Tuesday, October 16th, 2012',
#   'in the second presidential debate',
#   ['candidates-biography', 'job-accomplishments', 'states', 'women']],
#  [1,
#   ' George Bush never suggested that we eliminate funding for Planned Parenthood. ',
#   'barack-obama',
#   'Tuesday, October 16th, 2012',
#   'in in a town hall debate',
#   ['abortion', 'corrections-and-updates', 'debates']],
#  [1,
#   'Says Donald Trump was  forced to file for bankruptcy not once, not twice, four times. ',
#   'carly-fiorina',
#   'Wednesday, September 16th, 2015',
#   'in the CNN debate',
#   ['candidates-biography']],
#  [0,
#   'As a Member of Congress, Chris Murphy  was raking in $1 million in salary. ',
#   'linda-mcmahon',
#   'Thursday, October 11th, 2012',
#   'in a campaign ad',
#   ['candidates-biography']],
#  [0,
#   ' Regulations have quadrupled. The rate of regulations quadrupled under this president. ',
#   'mitt-romney',
#   'Tuesday, October 16th, 2012',
#   'in town hall presidential debate',
#   ['corrections-and-updates', 'market-regulation']],
#  [1,
#   'Says Mitt Romney suggested that  employers should be able to make the decision as to whether or not a woman gets contraception through her insurance coverage. ',
#   'barack-obama',
#   'Tuesday, October 16th, 2012',
#   'in the second presidential debate',
#   ['debates', 'drugs', 'health-care', 'sexuality', 'women']],
#  [0,
#   'Says Mitt Romney  called the Arizona law a model for the nation. ',
#   'barack-obama',
#   'Tuesday, October 16th, 2012',
#   'in the second presidential debate',
#   ['immigration', 'legal-issues']],
#  [0,
#   'Says Barack Obama began his presidency  with an apology tour. ',
#   'mitt-romney',
#   'Tuesday, October 16th, 2012',
#   'in the second presidential debate',
#   ['debates', 'foreign-policy']],
#  [1,
#   'Says Mitt Romney refused to say whether he d sign the Lilly Ledbetter bill.',
#   'barack-obama',
#   'Tuesday, October 16th, 2012',
#   'in the second presidential debate',
#   ['debates', 'women']],
#  [1,
#   'When Mitt Romney was governor of Massachusetts, he  stood in front of a coal plant and pointed at it and said,  This plant kills.  ',
#   'barack-obama',
#   'Tuesday, October 16th, 2012',
#   'in in a town-hall debate in Long Island, N.Y.',
#   ['debates', 'energy']],
#  [1,
#   ' We had a three-hour debate, no discussion about the national debt, very little about the economy. ',
#   'marco-rubio',
#   'Sunday, September 20th',
#   ' 2015 in an interview on This Week.',
#   ['debates', 'elections']],
#  [1,
#   'Says Obama broke his promise to offer a comprehensive immigration bill in his first year.',
#   'mitt-romney',
#   'Tuesday, October 16th, 2012',
#   'in the second presidential debate',
#   ['immigration']],
#  [0,
#   'Says six studies verify that the math adds up for Mitt Romney s tax plan.',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in the vice presidential debate',
#   ['taxes']],
#  [0,
#   'As governor,  Mitt Romney raised nursing home fees eight times. ',
#   'barack-obama',
#   'Tuesday, October 9th, 2012',
#   'in a campaign ad',
#   ['medicaid', 'message-machine-2012']],
#  [0,
#   'Says the Obama administration  watered down sanctions  against Iran, delayed them and tried to stop Congress  from putting the tough sanctions in place. ',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in the vice presidential debate',
#   ['foreign-policy', 'nuclear', 'terrorism', 'trade']],
#  [0,
#   'Says economists Harvey Rosen and Martin Feldstein have said that  paying for (Mitt) Romney s tax cuts would require large tax increases on families making between $100,000 and $200,000. ',
#   'barack-obama',
#   'Sunday, October 7th, 2012',
#   'in an email to supporters',
#   ['taxes']],
#  [0,
#   'Says Joe Biden  went to China and said that he sympathized and wouldn t second-guess their one-child policy of forced abortions and sterilizations. ',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in the vice presidential debate',
#   ['abortion', 'china']],
#  [1,
#   ' There s not one Democrat who endorses  the Romney-Ryan Medicare plan.',
#   'joe-biden',
#   'Thursday, October 11th, 2012',
#   'in a debate in Danville, Ky.',
#   ['bipartisanship', 'debates', 'medicare']],
#  [1,
#   ' The Canadians   they (dropped) their tax rates to 15 percent. The average tax rate on businesses in the industrialized world is 25 percent. ',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in the vice presidential debate in Danville, Ky.',
#   ['taxes']],
#  [1,
#   'Says David Vitter  answered a prostitute s call minutes after he skipped a vote honoring 28 soldiers who gave their lives in defense of our freedom. ',
#   'john-bel-edwards',
#   'Wednesday, November 11th, 2015',
#   'in a campaign ad',
#   ['candidates-biography', 'military', 'sexuality']],
#  [1,
#   ' There s never been a direct Supreme Court case on people who were here illegally, whether or not their kids are citizens. ',
#   'rand-paul',
#   'Wednesday, September 16th, 2015',
#   'in a presidential debate',
#   ['immigration', 'legal-issues']],
#  [0,
#   ' We weren t told they wanted more security   for diplomatic facilities in Libya.',
#   'joe-biden',
#   'Thursday, October 11th, 2012',
#   'in the vice presidential debate',
#   ['foreign-policy', 'terrorism']],
#  [0,
#   'Says Obama was in New York City the same day as Israeli Prime Minister Benjamin Netanyahu but went on a TV show instead of meeting with him.',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in in a debate',
#   ['debates', 'foreign-policy', 'israel']],
#  [0,
#   'Says the Obama administration spent taxpayer dollars on electric cars in Finland (and) windmills in China.',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in the vice-presidential debate',
#   ['stimulus']],
#  [0,
#   'Says Obama promised unemployment would never go above 8 percent.',
#   'paul-ryan',
#   'Thursday, October 11th, 2012',
#   'in a vice presidential debate',
#   ['jobs']],
#  [0,
#   ' When Congress voted to condemn Iran for sentencing a Christian pastor to death, (U.S. Rep. Lois) Capps was the only member who voted no. ',
#   'emergency-committee-israel',
#   'Tuesday, October 9th, 2012',
#   'in a campaign ad',
#   ['congressional-rules',
#    'foreign-policy',
#    'human-rights',
#    'islam',
#    'israel',
#    'religion']],
#  [0,
#   'Says Romney wants to  take away early childhood education, slash K-12 funding, and cut college aid   to pay for a $250,000 tax break for multi-millionaires. ',
#   'priorities-usa-action',
#   'Monday, October 8th, 2012',
#   'in a campaign ad',
#   ['education', 'message-machine-2012']],
#  [0,
#   ' You know our current president is (Muslim). You know he s not even an American.    ',
#   'town-hall-audience-member',
#   'Thursday, September 17th, 2015',
#   'in a town hall held by Donald Trump in Rochester, N.H.',
#   ['islam', 'obama-birth-certificate', 'terrorism']],
#  [0,
#   'Says Romney invested in a firm that made goods in China that  could have been made here in America. ',
#   'barack-obama',
#   'Monday, October 1st, 2012',
#   'in a campaign ad',
#   ['china', 'jobs', 'message-machine-2012']],
#  [0,
#   ' This is what President Obama said the jobless rate would be if we passed the stimulus: 5.6 percent. ',
#   'american-crossroads',
#   'Tuesday, October 2nd, 2012',
#   'in a TV ad',
#   ['candidates-biography',
#    'economy',
#    'jobs',
#    'message-machine-2012',
#    'stimulus']],
#  [1,
#   'The federal tax code has  loopholes that are giving incentives for companies that are shipping jobs overseas. ',
#   'barack-obama',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate',
#   ['debates', 'jobs', 'taxes']],
#  [0,
#   'Under Barack Obama, the U.S. now has the  lowest workforce since (President Jimmy) Carter. ',
#   'american-future-fund',
#   'Monday, October 1st, 2012',
#   'in a campaign ad',
#   ['economy', 'history', 'jobs', 'message-machine-2012']],
#  [0,
#   ' In one year, (President Obama) provided $90 billion in breaks to the green energy world   into solar and wind, to Solyndra and Fisker and Tesla and Ener1. ',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate in Denver',
#   ['candidates-biography',
#    'corporations',
#    'debates',
#    'energy',
#    'environment',
#    'stimulus']],
#  [0,
#   'Says 50 million people would lose their health insurance if Obamacare is repealed.',
#   'barack-obama',
#   'Wednesday, October 3rd, 2012',
#   'in a presidential debate',
#   ['debates', 'health-care']],
#  [0,
#   'Says President Obama has  doubled  the deficit.',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate in Denver',
#   ['debates', 'deficit', 'federal-budget']],
#  [0,
#   ' Pre-existing conditions are covered under my (health care) plan. ',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in a presidential debate in Denver',
#   ['debates', 'health-care']],
#  [0,
#   'The government  made accommodation to the Fort Hood shooter to let him grow a beard  for religious reasons.   ',
#   'mike-huckabee',
#   'Wednesday, September 16th, 2015',
#   'in the CNN Republican debate',
#   ['legal-issues', 'religion']],
#  [1,
#   'Massachusetts schools  are ranked No. 1 of all 50 states. ',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in a presidential debate in Denver',
#   ['debates', 'education', 'states']],
#  [1,
#   'Says Romney wants to add $2 trillion to the defense budget that the military hasn t asked for.',
#   'barack-obama',
#   'Wednesday, October 3rd, 2012',
#   'in a presidential debate in Denver',
#   ['debates', 'deficit', 'military', 'taxes']],
#  [0,
#   ' Under Gov. Romney s definition ... Donald Trump is a small business. ',
#   'barack-obama',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate in Denver',
#   ['debates', 'small-business', 'taxes']],
#  [0,
#   'Because of Obamacare,  over the last two years, health care premiums have gone up -- it s true -- but they ve gone up slower than any time in the last 50 years. ',
#   'barack-obama',
#   'Wednesday, October 3rd, 2012',
#   'in a debate in Denver',
#   ['debates', 'health-care']],
#  [1,
#   'Says Obama promised to cut the deficit in half.',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in a presidential debate',
#   ['debates', 'deficit']],
#  [0,
#   ' Right now, the (Congressional Budget Office) says up to 20 million people will lose their insurance as Obamacare goes into effect next year. ',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate in Denver',
#   ['debates', 'health-care']],
#  [0,
#   'Says Barack Obama  put in place a board that can tell people ultimately what treatments they re going to receive. ',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in a debate',
#   ['debates', 'medicare']],
#  [0,
#   'One of the Planned Parenthood videos shows  a fully formed fetus on the table, its heart beating, its legs kicking, while someone says,  We have to keep it alive to harvest its brain.   ',
#   'carly-fiorina',
#   'Wednesday, September 16th, 2015',
#   'in the CNN debate',
#   ['abortion', 'debates']],
#  [1,
#   ' We re now spending 42 percent of our economy on government. ',
#   'mitt-romney',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate in Denver',
#   ['debates', 'federal-budget', 'government-efficiency']],
#  [1,
#   'Romney  would turn Medicare into a voucher program. ',
#   'barack-obama',
#   'Wednesday, October 3rd, 2012',
#   'in the first presidential debate',
#   ['debates', 'medicare']],
#  [0,
#   'Says President Barack Obama  already passed all these Obamacare taxes. About a dozen of them hit middle-income taxpayers. ',
#   'paul-ryan',
#   'Sunday, September 30th, 2012',
#   'in an interview on Fox News Sunday',
#   ['health-care', 'taxes']],
#  [0,
#   'The Obama administration s  green  stimulus program  funneled close to $2 billion dollars to overseas firms,  creating thousands of jobs in China.',
#   'americans-tax-reform',
#   'Friday, September 28th, 2012',
#   'in a mailer to voters',
#   ['china', 'jobs', 'message-machine-2012', 'stimulus']],
#  [1,
#   'Chinese tire imports threatened 1,000 American jobs, so President Obama  stood up to China and protected American workers. Mitt Romney attacked Obama s decision. ',
#   'barack-obama',
#   'Monday, September 17th, 2012',
#   'in a television ad',
#   ['china', 'message-machine-2012', 'trade']],
#  [0,
#   'Says Mitt Romney s investments created zero jobs.',
#   'workers-voice',
#   'Monday, September 17th, 2012',
#   'in a mailer',
#   ['candidates-biography',
#    'corporations',
#    'economy',
#    'jobs',
#    'message-machine-2012']],
#  [1,
#   ' Taxes are lower on families than they ve been probably in the last 50 years. ',
#   'barack-obama',
#   'Sunday, September 23rd, 2012',
#   'in an interview on CBS 60 Minutes',
#   ['history', 'taxes']],
#  [0,
#   'Says Illinois Democrat David Gill  would end Medicare. ',
#   'national-republican-congressional-committee',
#   'Monday, September 10th, 2012',
#   'in a campaign commercial',
#   ['health-care', 'medicare', 'message-machine-2012']],
#  [0,
#   'Says the government has  gotten the TARP money back plus a profit. ',
#   'bill-clinton',
#   'Thursday, September 20th',
#   ' 2012 in an interview on The Daily Show',
#   ['financial-regulation']],
#  [1,
#   'Says Marco Rubio has  the worst voting record there is today. ',
#   'donald-trump',
#   'Wednesday, September 16th, 2015',
#   'in the second GOP primary debate.',
#   ['candidates-biography']],
#  [0,
#   ' Over the last four years, the deficit has gone up, but 90 percent of that is as a consequence of  President George W. Bush s policies and the recession.',
#   'barack-obama',
#   'Sunday, September 23rd, 2012',
#   'in an interview on CBS 60 Minutes',
#   ['debt', 'deficit', 'economy']],
#  [0,
#   ' Barack Hussein Obama will   force doctors to assist homosexuals in buying surrogate babies. ',
#   'government-not-god-pac',
#   'Sunday, September 23rd, 2012',
#   'in a newspaper advertisement',
#   ['gays-and-lesbians', 'health-care', 'religion']],
#  [0,
#   'Says Obama is only president in history who has deliberately removed the words  endowed by their Creator  when referring to the Declaration of Independence.',
#   'government-not-god-pac',
#   'Sunday, September 23rd, 2012',
#   'in a newspaper ad',
#   ['history', 'message-machine-2012']],
#  [0,
#   ' Barack Hussein Obama will ... force local authorities to allow Occupy protesters to live in parks. ',
#   'government-not-god-pac',
#   'Sunday, September 23rd, 2012',
#   'in a newspaper ad',
#   ['occupy-wall-street']],
#  [0,
#   ' Barack Hussein Obama will ... force Christian schools to hire non-Christian teachers. ',
#   'government-not-god-pac',
#   'Sunday, September 23rd, 2012',
#   'in a newspaper advertisement',
#   ['legal-issues', 'religion']],
#  [0,
#   ' Barack Hussein Obama will .. force Christian organizations to pay for abortions. ',
#   'government-not-god-pac',
#   'Sunday, September 23rd, 2012',
#   'in a newspaper ad',
#   ['abortion', 'message-machine-2012']],
#  [0,
#   ' Barack Hussein Obama will ... force courts to accept Islamic Sharia law in domestic disputes. ',
#   'government-not-god-pac',
#   'Sunday, September 23rd, 2012',
#   'in a newspaper ad',
#   ['islam', 'message-machine-2012']],
#  [0,
#   'Says Obama sent $450 million to China to build a wind farm in Texas.',
#   'americans-tax-reform',
#   'Friday, September 21st, 2012',
#   'in a mailer to voters',
#   ['china', 'jobs', 'message-machine-2012', 'stimulus']],
#  [0,
#   'College tuition  costs have risen by 25 percent under the Democrats. ',
#   'mitt-romney',
#   'Friday, September 21st, 2012',
#   'in a Spanish-language television ad',
#   ['education', 'message-machine-2012']],
#  [1,
#   'Says Obama adviser David Plouffe took  large piles of cash  from a joint venture partner of a company owned by Iran s Revolutionary Guard.',
#   'secure-america-now',
#   'Wednesday, September 12th, 2012',
#   'in a TV ad',
#   ['candidates-biography', 'foreign-policy', 'message-machine-2012']],
#  [0,
#   'Says Mexico doesn t have birthright citizenship, and Americans are the  only ones  to have it.',
#   'donald-trump',
#   'Wednesday, September 16th, 2015',
#   'in a GOP presidential debate on CNN',
#   ['immigration']],
#  [0,
#   'Says Romney tax plan  could take away middle-class deductions for child care, mortgages and college tuition. ',
#   'barack-obama',
#   'Tuesday, September 18th, 2012',
#   'in a campaign ad',
#   ['message-machine-2012', 'taxes']],
#  [0,
#   ' Eight million Americans have dropped out of the work force since (Barack) Obama became president. ... The real unemployment rate is 19 percent. ',
#   'restore-our-future',
#   'Wednesday, September 19th, 2012',
#   'in a campaign ad',
#   ['economy', 'jobs', 'message-machine-2012']],
#  [0,
#   ' Redistribution  has  never been a characteristic of America. ',
#   'mitt-romney',
#   'Wednesday, September 19th, 2012',
#   'in remarks in Atlanta',
#   ['economy', 'federal-budget', 'history', 'taxes']],
#  [1,
#   ' Even today part of Romney s fortune is invested in China. ',
#   'barack-obama',
#   'Thursday, September 13th, 2012',
#   'in a campaign ad',
#   ['china', 'message-machine-2012']],
#  [0,
#   'The  48, 49 percent  that supports President Barack Obama are  people who pay no income tax. ',
#   'mitt-romney',
#   'Thursday, May 17th, 2012',
#   'in a surreptitiously recorded speech to donors at a fundraiser',
#   ['taxes']],
#  [1,
#   ' Forty-seven percent of Americans pay no income tax. ',
#   'mitt-romney',
#   'Thursday, May 17th, 2012',
#   'in remarks at a campaign fundraiser',
#   ['taxes']],
#  [1,
#   ' Fifty percent of kids coming out of school can t get a job. ',
#   'mitt-romney',
#   'Thursday, May 17th, 2012',
#   'in a private campaign fundraiser',
#   ['education', 'jobs']],
#  [1,
#   ' The marijuana that kids are smoking today is not the same as the marijuana that Jeb Bush smoked 40 years ago.       ',
#   'carly-fiorina',
#   'Wednesday, September 16th, 2015',
#   'in the CNN Republican debate',
#   ['drugs']],
#  [0,
#   'Says President Obama promised  he d keep unemployment below 8 percent  if the stimulus passed.',
#   'mitt-romney',
#   'Thursday, May 17th, 2012',
#   'in a private campaign fundraiser',
#   ['economy']],
#  [0,
#   'Says five studies show his tax plan can cut rates and still bring the same revenue without raising taxes on the middle class.',
#   'mitt-romney',
#   'Sunday, September 9th, 2012',
#   'in a Meet the Press interview',
#   ['taxes']],
#  [0,
#   'Under Obama, home values in Florida collapsed, construction jobs were lost and the state had a high foreclosure rate.',
#   'mitt-romney',
#   'Friday, September 7th, 2012',
#   'in a campaign ad',
#   ['housing', 'message-machine-2012']],
#  [1,
#   'Says he and Mitt Romney  always said that we agree with the 2014 deadline  for leaving Afghanistan.',
#   'paul-ryan',
#   'Sunday, September 9th, 2012',
#   'in an appearance on This Week.',
#   ['afghanistan', 'foreign-policy']],
#  [0,
#   'On new dollar coins,   In God We Trust  is gone! ',
#   'chain-email',
#   'Tuesday, August 28th, 2012',
#   'in a chain email',
#   ['patriotism']],
#  [0,
#   ' We ve doubled our use of renewable energy. ',
#   'barack-obama',
#   'Saturday, September 8th, 2012',
#   'in a speech in Seminole, Fla.',
#   ['energy']],
#  [1,
#   'The Obama administration is allowing state waivers from welfare work requirements  only if they had a credible plan to increase employment by 20 percent. ',
#   'bill-clinton',
#   'Wednesday, September 5th, 2012',
#   'in a convention speech',
#   ['welfare']],
#  [1,
#   'Says President Barack Obama  gives students the right to repay (federal) loans as a clear, fixed, low percentage of their income for up to 20 years. ',
#   'bill-clinton',
#   'Wednesday, September 5th, 2012',
#   'in a speech at the Democratic National Convention in Charlotte, N.C.',
#   ['candidates-biography', 'education']],
#  [1,
#   'Says Romney called Russia our No. 1 enemy.',
#   'barack-obama',
#   'Thursday, September 6th, 2012',
#   'in a convention speech',
#   ['foreign-policy']],
#  [1,
#   ' I ve cut taxes for ... middle-class families, small businesses. ',
#   'barack-obama',
#   'Thursday, September 6th, 2012',
#   'in a speech at the Democratic National Convention in Charlotte, N.C.',
#   ['taxes']],
#  [1,
#   ' After a decade of decline, this country created over half a million manufacturing jobs in the last two and a half years. ',
#   'barack-obama',
#   'Thursday, September 6th, 2012',
#   'in his acceptance speech at the Democratic National Convention in Charlotte, N.C.',
#   ['economy', 'jobs']],
#  [0,
#   'When Social Security, Medicare and Medicaid were created,  Republicans stood on the sidelines ',
#   'james-clyburn',
#   'Thursday, September 6th, 2012',
#   'in a speech at the Democratic National Convention in Charlotte, N.C.',
#   ['health-care', 'history', 'medicaid', 'medicare']],
#  [0,
#   'Says Mitt Romney asked for a waiver from federal welfare rules.',
#   'rahm-emanuel',
#   'Sunday, September 2nd, 2012',
#   'in an appearance on Meet the Press',
#   ['welfare']],
#  [1,
#   'Under President Barack Obama s leadership,  since June 2009, (the auto) industry has added a quarter of a million jobs. ',
#   'bob-king',
#   'Wednesday, September 5th, 2012',
#   'in a speech to the Democratic National Convention in Charlotte, N.C.',
#   ['jobs']],
#  [1,
#   ' A majority of the men and women on this stage have previously and publicly embraced amnesty. I am the only candidate on this stage who has never supported amnesty. ',
#   'ted-cruz',
#   'Wednesday, September 16th, 2015',
#   'in comments during the CNN debate',
#   ['immigration']],
#  [1,
#   'Says U.S. Rep. Paul Ryan attacked the president for  the same amount of Medicare savings that (Ryan) had in his own budget. ',
#   'bill-clinton',
#   'Wednesday, September 5th, 2012',
#   'in a speech at the Democratic National Convention in Charlotte, N.C.',
#   ['federal-budget', 'medicare']],
#  [1,
#   ' In the last 29 months, our economy has produced about 4.5 million private-sector jobs. ',
#   'bill-clinton',
#   'Wednesday, September 5th, 2012',
#   'in a speech to the Democratic National Convention in Charlotte, N.C.',
#   ['economy', 'jobs']],
#  [1,
#   ' Since 1961   our private economy has produced 66 million private-sector jobs. So what s the jobs score? Republicans 24 million, Democrats 42 (million). ',
#   'bill-clinton',
#   'Wednesday, September 5th, 2012',
#   'in a speech to the Democratic National Convention in Charlotte, N.C.',
#   ['economy', 'history', 'jobs']],
#  [1,
#   'Women  receive only 77 cents for every dollar a man earns. ',
#   'diana-degette',
#   'Wednesday, September 5th, 2012',
#   'in a Democratic National Convention speech',
#   ['jobs', 'women']],
#  [0,
#   'When it comes to jobless workers,  Mitt Romney says he likes to fire people. ',
#   'jack-markell',
#   'Wednesday, September 5th, 2012',
#   'in a speech at the Democratic National Convention in Charlotte, N.C. ',
#   ['candidates-biography', 'workers']],
#  [1,
#   ' Seven presidents before (Barack Obama) -- Republicans and Democrats -- tried to expand health care to all Americans. ',
#   'julian-castro',
#   'Tuesday, September 4th, 2012',
#   'in a keynote speech to the Democratic National Convention in Charlotte, N.C.',
#   ['health-care', 'history']],
#  [0,
#   'Says Wisconsin Gov. Scott Walker turned a $1 billion surplus into a $2.2 billion budget deficit.',
#   'donald-trump',
#   'Wednesday, September 16th, 2015',
#   'in the CNN debate',
#   ['economy']],
#  [1,
#   'At Bain Capital,  we helped start an early childhood learning company called Bright Horizons that First Lady Michelle Obama rightly praised. ',
#   'mitt-romney',
#   'Thursday, August 30th, 2012',
#   'in remarks at the Republican National Convention in Tampa',
#   ['candidates-biography', 'job-accomplishments']],
#  [1,
#   'In his first TV interview as president, Obama said we  should talk to Iran. ',
#   'mitt-romney',
#   'Thursday, August 30th, 2012',
#   'in remarks at the Republican National Convention in Tampa',
#   ['foreign-policy']],
#  [0,
#   'Barack Obama began his presidency  with an apology tour. ',
#   'mitt-romney',
#   'Thursday, August 30th, 2012',
#   'in  remarks at the Republican National Convention in Tampa',
#   ['foreign-policy']],
#  [0,
#   'President Barack Obama has  weakened the respect for America abroad. ',
#   'callista-gingrich',
#   'Thursday, August 30th, 2012',
#   'in a speech at the Republican National Convention in Tampa',
#   ['foreign-policy', 'polls']],
#  [0,
#   'President Obama  funneled  $716 billion out of Medicare  at the expense of the elderly. ',
#   'paul-ryan',
#   'Wednesday, August 29th, 2012',
#   'in a speech at the Republican National Convention',
#   ['federal-budget', 'medicare']],
#  [0,
#   ' There is currently no ability to vet these people,  referring to Syrian refugees.',
#   'ben-carson',
#   'Monday, November 16th, 2015',
#   'in an official statement posted on Facebook.',
#   ['foreign-policy', 'homeland-security', 'immigration', 'terrorism']],
#  [1,
#   ' The top man at Yale Law School came out ... with just a raging report  about former HP CEO Carly Fiorina, saying she is  one of the worst executives in his memory in history running the company. ',
#   'donald-trump',
#   'Sunday, September 13th, 2015',
#   'in an interview on Face the Nation',
#   ['candidates-biography']],
#  [0,
#   'The Obama administration  even proposed banning farm kids from doing basic chores! ',
#   'john-thune',
#   'Wednesday, August 29th, 2012',
#   'in at the Republican National Convention in Tampa',
#   ['agriculture', 'government-regulation']],
#  [0,
#   'Barack Obama has  never even worked in business. ',
#   'rob-portman',
#   'Wednesday, August 29th, 2012',
#   'in a speech at the Republican National Convention in Tampa',
#   ['candidates-biography']],
#  [0,
#   'When his grandfather arrived in the United States,  there were no government benefits for immigrants. ',
#   'rick-santorum',
#   'Tuesday, August 28th, 2012',
#   'in a speech at the Republican National Convention in Tampa',
#   ['welfare']],
#  [0,
#   ' A report just came out that if we continue with President Obama s policies, we re looking at over 9 percent unemployment next year in the fourth quarter. ',
#   'michele-bachmann',
#   'Monday, August 27th, 2012',
#   'in a Fox News interview',
#   ['economy', 'federal-budget', 'jobs']],
#  [0,
#   'The health care law imposes a federal mandate requiring middle-class Americans to buy health insurance  whether they can afford it or not. ',
#   'artur-davis',
#   'Tuesday, August 28th, 2012',
#   'in a speech at the Republican National Convention in Tampa',
#   ['health-care']],
#  [1,
#   'There has been  $5 trillion in debt added over the last four years. ',
#   'chris-christie',
#   'Tuesday, August 28th, 2012',
#   'in a speech at the Republican National Convention in Tampa',
#   ['debt']],
#  [0,
#   'Says President Obama has waived  the work requirement for welfare. ',
#   'rick-santorum',
#   'Tuesday, August 28th, 2012',
#   'in a convention speech',
#   ['welfare']],
#  [1,
#   'Mitt Romney  gave away his father s inheritance. ',
#   'reince-priebus',
#   'Sunday, August 26th, 2012',
#   'in a TV interview',
#   ['candidates-biography', 'wealth']],
#  [1,
#   ' I m the only governor in America ... who signed a law that says there needs to be an independent investigation any time there s a death of someone in police custody. ',
#   'scott-walker',
#   'Sunday, September 13th, 2015',
#   'in an interview on CNNs State of the Union',
#   ['criminal-justice']],
#  [0,
#   'In the past 27 months, President Barack Obama has created more private-sector jobs than  in the Reagan recovery. ',
#   'stephanie-cutter',
#   'Wednesday, August 22nd, 2012',
#   'in an interview on MSNBCs Morning Joe',
#   ['economy', 'history', 'jobs']],
#  [1,
#   ' In 2008, candidate Barack Obama attacked John McCain for proposing cuts to Medicare. ',
#   'mitt-romney',
#   'Sunday, August 26th, 2012',
#   'in a campaign ad',
#   ['medicare', 'message-machine-2012']],
#  [1,
#   ' Mitt Romney says class sizes don t matter. ',
#   'barack-obama',
#   'Wednesday, August 22nd, 2012',
#   'in a campaign ad',
#   ['education', 'message-machine-2012']],
#  [0,
#   'The Obama administration  leaked information, deliberately or otherwise, that led to the identification of the Pakistani doctor that helped us in achieving our goals and killing bin Laden. ',
#   'special-operations-opsec-education-fund',
#   'Wednesday, August 15th, 2012',
#   'in a web video',
#   ['foreign-policy', 'message-machine-2012', 'military', 'terrorism']],
#  [0,
#   ' Days after the (Osama bin Laden) raid, Hollywood was invited into the White House so that they could receive a briefing  that revealed intelligence sources and methods.',
#   'special-operations-opsec-education-fund',
#   'Wednesday, August 15th, 2012',
#   'in a Web video',
#   ['foreign-policy', 'message-machine-2012', 'military', 'terrorism']],
#  [1,
#   'Says Mitt Romney and Paul Ryan  want to turn Medicare into a voucher system. ',
#   'barack-obama',
#   'Wednesday, August 15th, 2012',
#   'in remarks at a campaign event',
#   ['federal-budget', 'health-care', 'medicare']],
#  [0,
#   ' The Iran Deal will facilitate and accelerate the nation of Iran acquiring nuclear weapons.    ',
#   'ted-cruz',
#   'Wednesday, September 9th, 2015',
#   'in a tweet',
#   ['corrections-and-updates', 'foreign-policy', 'nuclear']],
#  [0,
#   'Says Barack Obama  robbed Medicare (of) $716 billion to pay for ... Obamacare. ',
#   'mitt-romney',
#   'Sunday, August 12th, 2012',
#   'in an interview on 60 Minutes',
#   ['federal-budget', 'history', 'medicare', 'retirement']],
#  [1,
#   'Says Paul Ryan s budget relies on the same $700 billion in savings from Medicare that Mitt Romney and other Republicans have been attacking Democrats about.',
#   'stephanie-cutter',
#   'Sunday, August 12th, 2012',
#   'in an interview on Face the Nation',
#   ['federal-budget', 'health-care', 'medicare', 'retirement']],
#  [1,
#   'Says Mitt Romney  wants to end tax credits for wind producers. ',
#   'barack-obama',
#   'Thursday, August 9th, 2012',
#   'in a campaign event',
#   ['energy']],
#  [0,
#   'Says U.S. Rep. Martin Heinrich  spent a trillion of our tax dollars on a stimulus for failed companies here and jobs overseas. ',
#   'american-future-fund',
#   'Thursday, August 9th, 2012',
#   'in an advertisement',
#   ['jobs', 'message-machine-2012', 'stimulus']],
#  [0,
#   ' Gov. Romney himself, with 28 other Republican governors, supported policies that would have eliminated the time limits in the welfare reform law and allowed people to stay on welfare forever. ',
#   'jay-carney',
#   'Tuesday, August 7th, 2012',
#   'in a press White House press briefing',
#   ['welfare']],
#  [0,
#   'Says Mitt Romney and Bain Capital are to blame in a woman s premature death when they closed the plant where her husband worked.',
#   'priorities-usa-action',
#   'Tuesday, August 7th, 2012',
#   'in campaign ad',
#   ['economy', 'message-machine-2012']],
#  [0,
#   ' In June, jobless ranks were higher in nearly 90 percent of U.S. cities. ',
#   'mitt-romney',
#   'Sunday, August 5th, 2012',
#   'in a campaign ad',
#   ['economy', 'jobs', 'message-machine-2012']],
#  [0,
#   ' Unions did not create  the eight-hour work day and the 40-hour work week.  Henry Ford did. ',
#   'viral-image',
#   'Sunday, September 6th, 2015',
#   'in a Facebook post',
#   ['history', 'jobs', 'labor']],
#  [1,
#   'Says Mitt Romney opposes requiring employers to cover contraception and would eliminate funding for Planned Parenthood.',
#   'barack-obama',
#   'Saturday, August 4th, 2012',
#   'in a campaign ad',
#   ['abortion', 'message-machine-2012', 'sexuality', 'women']],
#  [0,
#   ' Under Obama s plan (for welfare), you wouldn t have to work and wouldn t have to train for a job. They just send you your welfare check. ',
#   'mitt-romney',
#   'Monday, August 6th, 2012',
#   'in a campaign ad',
#   ['message-machine-2012', 'welfare']],
#  [1,
#   ' As president, Barack Obama has never visited Israel. ',
#   'mitt-romney',
#   'Sunday, August 5th, 2012',
#   'in a campaign ad',
#   ['israel', 'message-machine-2012']],
#  [0,
#   'Says Mitt Romney did not pay taxes for 10 years.',
#   'harry-reid',
#   'Tuesday, July 31st, 2012',
#   'in an interview with the Huffington Post',
#   ['candidates-biography', 'taxes']],
#  [1,
#   'Mitt Romney is proposing a tax plan  that would give millionaires another tax break and raises taxes on middle class families by up to $2,000 a year. ',
#   'barack-obama',
#   'Wednesday, August 1st, 2012',
#   'in a TV ad',
#   ['message-machine-2012', 'taxes']],
#  [1,
#   ' One out of every two kids who are graduating college right now can t find a job. ',
#   'republican-jewish-coalition',
#   'Monday, June 18th, 2012',
#   'in a campaign ad',
#   ['economy', 'message-machine-2012']],
#  [0,
#   ' U.S. Olympic medal winners will owe up to $9,000 to the IRS. ',
#   'americans-tax-reform',
#   'Tuesday, July 31st, 2012',
#   'in a blog post',
#   ['sports', 'taxes']],
#  [1,
#   ' Today the Walton family of Walmart own more wealth than the bottom 40 percent of America. ',
#   'bernie-s',
#   'Sunday, July 22nd, 2012',
#   'in a message on Twitter',
#   ['economy']],
#  [0,
# ...
#   ' ',
#   'al-hunt',
#   'Sunday, August 22nd, 2010',
#   ['in ABCs This Week']],
#  [0,
#   'Under the new health care law,  all real estate transactions will be subject to a 3.8% Sales Tax ',
#   'chain-email',
#   'Monday, August 2nd, 2010',
#   'in a chain e-mail',
#   ['health-care', 'market-regulation', 'taxes']],
#  [1,
#   ' The Republicans have 2 percent of the Muslim vote.  ',
#   'tamara-holder',
#   'Wednesday, August 18th, 2010',
#   'in comments on the Hannity show.',
#   ['religion']],
#  [0,
#   'A New York imam wants to  have a mosque at Ground Zero.   ',
#   'rick-lazio',
#   'Tuesday, August 17th, 2010',
#   'in Fox News Hannity program.',
#   ['homeland-security', 'patriotism', 'religion']],
#  [1,
#   ' U.S. taxpayers are being forced to fund Feisal Abdul Rauf s trip to the Middle East. ',
#   'ileana-ros-lehtinen',
#   'Tuesday, August 10th, 2010',
#   'in a press release.',
#   ['foreign-policy', 'religion', 'terrorism']],
#  [0,
#   ' Some Republican leaders in Congress  are  pushing to make privatizing Social Security a key part of their legislative agenda if they win a majority in Congress this fall. ',
#   'barack-obama',
#   'Saturday, August 14th, 2010',
#   'in his weekly address',
#   ['social-security']],
#  [1,
#   ' In 1935, more than 50% of the elderly population lived in poverty. Today that poverty rate stands officially at 9.4%.  ',
#   ' ',
#   'eddie-bernice-johnson',
#   'Tuesday, August 10th, 2010',
#   ['in a speech on the House floor.']],
#  [1,
#   'Says Hillary Clinton  was completely exonerated, when I was in the White House  by an official inquiry on Whitewater.',
#   'bill-clinton',
#   'Sunday, June 14th, 2015',
#   'in comments on CNNs State of the Union',
#   ['candidates-biography', 'history']],
#  [1,
#   ' Unemployment for those with college educations is now 4.5 percent. Unemployment for those with more than a college education, below 4 percent. ',
#   'laura-tyson',
#   'Sunday, August 15th, 2010',
#   'in an interview on ABCs This Week with Christiane Amanpour',
#   ['economy', 'education', 'abc-news-week']],
#  [1,
#   'Obama s approval numbers  are in the low 40s. ',
#   'matthew-dowd',
#   'Sunday, August 15th, 2010',
#   'in a roundtable discussion on ABCs This Week with Christiane Amanpour',
#   ['pundits', 'abc-news-week']],
#  [0,
#   'A bill to aid state and local governments  is fully paid-for by closing costly corporate tax loopholes. ',
#   'nancy-pelosi',
#   'Tuesday, August 10th, 2010',
#   'in a news release',
#   ['children',
#    'education',
#    'families',
#    'federal-budget',
#    'health-care',
#    'states',
#    'stimulus',
#    'taxes']],
#  [1,
#   ' The overall fact about illegal immigration is that it s not actually getting worse. ',
#   'rachel-maddow',
#   'Monday, August 2nd, 2010',
#   'in The Rachel Maddow Show',
#   ['immigration', 'pundits']],
#  [0,
#   'McCain opposed the border fence.',
#   'jd-hayworth',
#   'Thursday, August 5th, 2010',
#   'in a TV ad against John McCain',
#   ['immigration', 'message-machine']],
#  [0,
#   'Despite the U.S. spending $10 billion on Iraq s electrical system, Baghdad still only gets five hours of electricity a day.',
#   'george-packer',
#   'Sunday, August 8th, 2010',
#   'in ABCs This Week',
#   ['energy', 'infrastructure', 'iraq', 'abc-news-week']],
#  [0,
#   ' There s still about $400 billion or $500 billion of the stimulus plan that has not been spent. Why don t we stop it. ',
#   'john-boehner',
#   'Sunday, August 8th, 2010',
#   'in an interview on NBCs Meet the Press',
#   ['federal-budget', 'stimulus', 'taxes']],
#  [1,
#   'About 106,000 soldiers had  a prescription of three weeks or more  for pain, depression or anxiety medication.',
#   'gen-peter-chiarelli',
#   'Sunday, August 8th, 2010',
#   'in an interview on This Week.',
#   ['health-care', 'military', 'abc-news-week']],
#  [0,
#   'Democrats do not have a plan for extending the Bush tax cuts.',
#   'sarah-palin',
#   'Thursday, August 5th, 2010',
#   'in a note on Facebook.',
#   ['taxes']],
#  [0,
#   ' Canada sets aside 36 percent of their visas for people with skills they think their country needs.  We set aside 6 percent. ',
#   'michael-bloomberg',
#   'Sunday, August 1st, 2010',
#   'in an interview on Meet the Press.',
#   ['immigration']],
#  [0,
#   ' Democrats are poised now to cause this largest tax increase in U.S. history. ',
#   'sarah-palin',
#   'Sunday, August 1st, 2010',
#   'in an interview on Fox News Sunday',
#   ['taxes']],
#  [0,
#   ' Ninety-four percent of small businesses will face higher taxes under the Democrats  plan. ',
#   'randy-neugebauer',
#   'Thursday, July 29th, 2010',
#   'in a Townhall.com guest blog post',
#   ['economy', 'federal-budget', 'taxes']],
#  [1,
#   ' Eight of the nine justices in the Supreme Court decision (on campaign finance) said that not only is it constitutional for Congress to require disclosure of the special interest money, but they recommend we do it. ',
#   'charles-schumer',
#   'Tuesday, July 27th, 2010',
#   'in a press conference',
#   ['campaign-finance', 'supreme-court']],
#  [1,
#   ' Here are the stats: Per population, we kill each other with guns at a rate 297x more than Japan, 49x more than France, 33x more than Israel. ',
#   'barack-obama',
#   'Saturday, June 20th',
#   ' 2015 in a tweet',
#   ['crime', 'criminal-justice', 'guns']],
#  [1,
#   'House Democrats  have a two-to-one advantage money-wise  against House Republicans.',
#   'nancy-pelosi',
#   'Sunday, August 1st, 2010',
#   'in an interview on ABCs This Week',
#   ['campaign-finance', 'elections', 'abc-news-week']],
#  [0,
#   ' This is the first time since the Depression that unemployment has stayed above 9 percent for two consecutive years. ',
#   'john-boehner',
#   'Sunday, August 1st, 2010',
#   'in an interview on Fox News Sunday',
#   ['economy', 'history']],
#  [1,
#   'During the recession,  the consumer in his native perversity has begun to save. The savings rate is now 6.2 percent. ',
#   'george-will',
#   'Sunday, August 1st, 2010',
#   'in a roundtable discussion on ABCs This Week',
#   ['economy', 'abc-news-week']],
#  [0,
#   'When Obama went to Pakistan in 1981, he could not have been traveling as a U.S. citizen.',
#   'chain-email',
#   'Monday, June 28th, 2010',
#   'in a chain e-mail.',
#   ['candidates-biography', 'obama-birth-certificate']],
#  [0,
#   'A transcript released by Occidental College proves that Barack Obama was an Indonesian citizen.',
#   'chain-email',
#   'Monday, June 28th, 2010',
#   'in a chain e-mail',
#   ['candidates-biography', 'obama-birth-certificate']],
#  [0,
#   'Justice Antonin Scalia agreed for the Supreme Court to hear a case about whether Barack Obama is eligible to be President.',
#   'chain-email',
#   'Monday, June 28th, 2010',
#   'in a chain e-mail',
#   ['candidates-biography', 'obama-birth-certificate', 'supreme-court']],
#  [0,
#   ' I don t think the argument can be credibly made that the United States of America is undertaxed compared to our competitors. ',
#   'tim-pawlenty',
#   'Monday, July 26th, 2010',
#   'in a breakfast with journalists in Washington, D.C.',
#   ['taxes']],
#  [1,
#   'The president s budget  would take ... non-defense spending to its lowest level ... as a percentage of the economy since JFK. ',
#   'barack-obama',
#   'Thursday, July 22nd, 2010',
#   'in remarks at a bill signing',
#   ['economy', 'federal-budget', 'military']],
#  [0,
#   ' This type of mass violence does not happen in other advanced countries. It doesn t happen in other places with this kind of frequency. ',
#   'barack-obama',
#   'Thursday, June 18th, 2015',
#   'in remarks at the White House',
#   ['corrections-and-updates', 'crime', 'criminal-justice', 'guns']],
#  [1,
#   'Over the last 10 years, incomes for the top 1 percent  have grown.  Meanwhile, the bottom half of the country,  they ve seen their wages stagnate. ',
#   'donna-brazile',
#   'Sunday, July 25th, 2010',
#   'in a roundtable discussion on ABCs This Week',
#   ['economy', 'pundits', 'abc-news-week']],
#  [0,
#   ' 25 percent of our economy is the financial sector. ',
#   'david-gregory',
#   'Sunday, July 25th, 2010',
#   'in an interview with Treasury Secretary Timothy Geithner on NBCs Meet the Press',
#   ['corporations', 'economy', 'financial-regulation', 'pundits']],
#  [1,
#   'The Latino unemployment rate is higher than the white rate and the black rate is higher than the Latino rate.',
#   'marc-morial',
#   'Sunday, July 25th, 2010',
#   'in a roundtable discussion on NBCs Meet the Press',
#   ['diversity', 'economy', 'workers']],
#  [0,
#   'People in the top tax bracket,  these so-called wealthy, most of them are small-business owners. ',
#   'stephen-hayes',
#   'Sunday, July 25th, 2010',
#   'in on ABC News This Week.',
#   ['small-business', 'taxes', 'abc-news-week']],
#  [1,
#   ' We ve seen six months of positive job growth by the private sector. ',
#   'timothy-geithner',
#   'Sunday, July 25th, 2010',
#   'in ABCs This Week',
#   ['economy', 'abc-news-week']],
#  [1,
#   'Shirley Sherrod  was forced to resign before anybody on Fox said a word about this. ',
#   'stephen-hayes',
#   'Sunday, July 25th, 2010',
#   'in a roundtable discussion on ABCs This Week',
#   ['agriculture', 'diversity', 'pundits', 'abc-news-week']],
#  [1,
#   ' Ken Buck s (District Attorney s) office? His spending skyrocketed by 40 percent. ',
#   'jane-norton',
#   'Friday, July 9th, 2010',
#   'in a television ad',
#   ['crime', 'message-machine', 'states']],
#  [0,
#   'The Democrats are  responsible  for  the swift, mindless drawdown of a military that was generations in the making. ',
#   'jeb-bush',
#   'Monday, June 15th, 2015',
#   'in his presidential announcement speech',
#   ['federal-budget', 'military']],
#  [0,
#   ' Attorney General Eric Holder is involved in the dismissal of the criminal charges  against the New Black Panther Party for voter intimidation  ',
#   'bill-oreilly',
#   'Saturday, July 17th, 2010',
#   'in an online column',
#   ['civil-rights', 'crime', 'elections', 'pundits']],
#  [0,
#   ' Of all the illegals in America, more than half come through Arizona. ',
#   'john-mccain',
#   'Friday, May 7th, 2010',
#   'in a campaign ad',
#   ['immigration', 'message-machine']],
#  [0,
#   ' Recent data showed Nevada ranks 50th in the money received from  the stimulus bill.',
#   'american-crossroads',
#   'Sunday, July 18th, 2010',
#   'in a campaign commercial',
#   ['federal-budget', 'message-machine', 'stimulus']],
#  [0,
#   'Obama s dog has his  own plane ',
#   'blog-posting',
#   'Saturday, July 17th, 2010',
#   'in conservative blogs',
#   ['transportation']],
#  [0,
#   ' Should Democrats get their way, every income tax bracket will increase on Jan. 1, 2011. Every single one. ',
#   'mike-pence',
#   'Tuesday, July 20th',
#   ' 2010 in a press conference',
#   ['taxes']],
#  [0,
#   ' Sixty percent of the Hispanics  support the Arizona immigration law',
#   'russell-pearce',
#   'Wednesday, July 7th, 2010',
#   'in a CNN interview',
#   ['immigration']],
#  [1,
#   ' I never called for a partition  of Iraq.',
#   'joe-biden',
#   'Sunday, July 18th, 2010',
#   'in ABCs This Week',
#   ['iraq', 'abc-news-week']],
#  [0,
#   ' The health care numbers are going up. ',
#   'joe-biden',
#   'Sunday, July 18th, 2010',
#   'in an interview on ABCs This Week',
#   ['health-care', 'abc-news-week']],
#  [1,
#   'The original compromise for the Confederate battle flag in South Carolina  was to put it on the back side of the statehouse, out of public view so it would not have any appearance of sovereignty. ',
#   'james-clyburn',
#   'Sunday, June 21st, 2015',
#   'in comments on NBCs Meet the Press',
#   ['diversity', 'history', 'states']],
#  [0,
#   'Russ Feingold  voted against the law that protected our lakes  and  was the only Great Lakes senator to vote no. ',
#   'ron-johnson',
#   'Wednesday, July 14th, 2010',
#   'in a campaign commercial',
#   ['energy', 'environment', 'message-machine']],
#  [1,
#   'As a Congressman, J.D. Hayworth was an avid earmarker who supported such pork as  $220,000 to renovate a Maine Blueberry farm  and  $5.8 million for a Vermont snowmobile trail. ',
#   'john-mccain',
#   'Wednesday, May 26th, 2010',
#   'in a political ad',
#   ['federal-budget', 'message-machine']],
#  [0,
#   'The Obama administration will give Pennsylvania $160 million to pay for health insurance plans that cover  any legal abortion. ',
#   'national-right-life-committee',
#   'Tuesday, July 13th, 2010',
#   'in a prepared statement',
#   ['abortion', 'health-care', 'states']],
#  [1,
#   ' We went from losing 3 million jobs in the last six months of the Bush Administration,  adding almost 600,000 private sector jobs in the first six months of the year.',
#   'joe-biden',
#   'Wednesday, July 14th, 2010',
#   'in a news conference',
#   ['economy', 'government-efficiency', 'job-accomplishments']],
#  [1,
#   ' We re spending $1 trillion a year on our foreign policy. ',
#   'ron-paul',
#   'Monday, July 5th, 2010',
#   'in a CNN interview',
#   ['federal-budget', 'foreign-policy', 'military']],
#  [1,
#   'Under President George W. Bush, the U.S. had  52 months of ... uninterrupted job creation  and  revenues were at an all-time high in 2007. ',
#   'ed-gillespie',
#   'Sunday, July 11th, 2010',
#   'in an appearance on NBCs Meet the Press',
#   ['economy', 'history', 'taxes']],
#  [1,
#   'Republicans extended unemployment insurance under President Bush  when he asked to extend unemployment insurance. ',
#   'david-axelrod',
#   'Sunday, July 11th, 2010',
#   'in an interview on This Week.',
#   ['abc-news-week', 'workers']],
#  [1,
#   'Says income tax rates under Eisenhower were as high as 90 percent.',
#   'bernie-s',
#   'Saturday, November 14th, 2015',
#   'in a Democratic presidential debate in Des Moines, Iowa',
#   ['taxes']],
#  [0,
#   ' Even our nuclear arsenal doesn t work. It came out recently they have equipment that is 30 years old. They don t know if it worked. ',
#   'donald-trump',
#   'Tuesday, June 16th, 2015',
#   'in his presidential announcement speech',
#   ['military', 'nuclear']],
#  [0,
#   'Says that President Obama said if Congress passed the economic stimulus bill,  we would have unemployment at 8 percent and no higher. And it went higher. ',
#   'george-will',
#   'Sunday, July 11th, 2010',
#   'in ABCs This Week',
#   ['pundits', 'stimulus', 'abc-news-week']],
#  [1,
#   '"Forty percent of the undocumented workers in this country" entered the U.S. legally and "overstayed their visa.',
#   'luis-gutierrez',
#   'Sunday, July 11th, 2010',
#   'in an interview on ABCs This Week',
#   ['immigration', 'legal-issues', 'abc-news-week']],
#  [0,
#   ' The top 1 percent pay over half of the entire revenue for this country. ',
#   'trent-franks',
#   'Wednesday, July 7th, 2010',
#   'in an interview on MSNBCs The Dylan Ratigan Show',
#   ['taxes']],
#  [0,
#   'The U.S. "only ranks 25th worldwide on defense spending as a percentage of GDP.',
#   'sarah-palin',
#   'Wednesday, June 30th, 2010',
#   'in a Facebook posting',
#   ['federal-budget', 'foreign-policy', 'military']],
#  [1,
#   '"We spend three times more on entitlements and debt services than we do on defense.',
#   'sarah-palin',
#   'Wednesday, June 30th, 2010',
#   'in a Facebook posting',
#   ['federal-budget', 'social-security']],
#  [0,
#   ' Subsidies for oil and gas companies make up 88 percent of all federal subsidies. Just cutting the oil and gas subsidies out would save the U.S. government $45 billion every year. ',
#   'keith-olbermann',
#   'Tuesday, July 6th, 2010',
#   'in a comment on MSNBCs Countdown with Keith Olbermann',
#   ['energy', 'federal-budget', 'oil-spill', 'pundits', 'taxes']],
#  [1,
#   '"He (Kirk) did violate Pentagon rules, twice actually, for improperly mingling politics with his military service.',
#   'alexi-giannoulias',
#   'Thursday, July 8th, 2010',
#   'in a campaign commercial',
#   ['afghanistan',
#    'candidates-biography',
#    'iraq',
#    'message-machine',
#    'military',
#    'patriotism']],
#  [0,
#   '"Alexi Giannoulias\' top aide was a longtime BP lobbyist.',
#   'mark-kirk',
#   'Thursday, July 8th, 2010',
#   'in a campaign ad',
#   ['message-machine', 'oil-spill']],
#  [1,
#   ' The gap between the very rich and everyone else in America is wider today than at any time since the 1920s. ',
#   'bernie-s',
#   'Thursday, June 4th, 2015',
#   'in a post on Twitter',
#   ['economy', 'income']],
#  [1,
#   '"Crime is down in Arizona.',
#   'al-hunt',
#   'Sunday, July 4th, 2010',
#   'in an appearance on ABCs This Week.',
#   ['crime', 'immigration', 'abc-news-week']],
#  ...]

# %% [markdown]
# ## Q6 - Does Trump lie? (in this data set)
#
# How many lies (0's) and how many truths (1's) that Donald Trump said are in our data set? Donald Trump's identifier is 'donald-trump'. Print the numbers

# %%
trump = dict()

for i in range(0,len(new_statements)):
    if new_statements[i][2] == 'donald-trump':
        if new_statements[i][0] in trump:
            trump[new_statements[i][0]] +=1
        else:
            trump[new_statements[i][0]] =1 
trump
# Out:
# {0: 44, 1: 5}

# %% [markdown]
# ## Q7 - How about Hillary and Obama? (in this data set)
#
# Perform the same exercise for Hillary, and for Obama. Their respective identifiers are 'hillary-clinton' and 'barack-obama'

# %%
hillary = dict()

for i in range(0,len(new_statements)):
    if new_statements[i][2] == 'hillary-clinton':
        if new_statements[i][0] in hillary:
            hillary[new_statements[i][0]] +=1
        else:
            hillary[new_statements[i][0]] =1 
hillary
# Out:
# {0: 36, 1: 62}

# %%
obama = dict()

for i in range(0,len(new_statements)):
    if new_statements[i][2] == 'barack-obama':
        if new_statements[i][0] in obama:
            obama[new_statements[i][0]] +=1
        else:
            obama[new_statements[i][0]] =1 
obama
# Out:
# {1: 248, 0: 136}

# %% [markdown]
# ## Q8 - Obama's favorite subjects
#
# What are the top 10 subjects obama talks about? Use the new_statements list for this question. If one statement is on more than one subject, then it counts as a +1 for every subject it is about. Print the top 10, along with the number of mentions.

# %%
topics = list()
total = list()

for i in range(0,len(new_statements)):
    if new_statements[i][2] == 'barack-obama':
        topics.append(new_statements[i][5])

for i in topics:
    total += i
total.pop(664)

obama_fav = dict()

for i in range(0,len(total)):
    if total[i] in obama_fav:
        obama_fav[  (total[i])  ] += 1
    else:
        obama_fav[  (total[i]) ] = 1

# %%
sorted_obama = []
for k in obama_fav:
    sorted_obama.append([obama_fav[k],k])
sorted_obama[:10]
# Out:
# [[39, 'federal-budget'],
#  [5, 'polls'],
#  [44, 'taxes'],
#  [6, 'crime'],
#  [5, 'criminal-justice'],
#  [11, 'legal-issues'],
#  [9, 'environment'],
#  [2, 'poverty'],
#  [9, 'workers'],
#  [39, 'energy']]

# %%
sorted_obama.sort(key=lambda x: x[0])
sorted_obama.reverse()
sorted_obama[:10]
# Out:
# [[63, 'health-care'],
#  [60, 'economy'],
#  [44, 'taxes'],
#  [39, 'energy'],
#  [39, 'federal-budget'],
#  [25, 'jobs'],
#  [24, 'message-machine-2012'],
#  [21, 'foreign-policy'],
#  [16, 'history'],
#  [14, 'candidates-biography']]
